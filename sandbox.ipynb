# %%
import pandas as pd

df = pd.read_csv("Video_games.csv", header=0)

# %%
df["JP_Sales"].min()
# Out:
# 0.0

# %%
df[['Platform', 'JP_Sales', 'NA_Sales', 'EU_Sales']].groupby("Platform").count()
# Out:
#           JP_Sales  NA_Sales  EU_Sales
# Platform
# 2600           133       133       133
# 3DO              3         3         3
# 3DS            520       520       520
# DC              52        52        52
# DS            2152      2152      2152
# GB              98        98        98
# GBA            822       822       822
# GC             556       556       556
# GEN             29        29        29
# GG               1         1         1
# N64            319       319       319
# NES             98        98        98
# NG              12        12        12
# PC             974       974       974
# PCFX             1         1         1
# PS            1197      1197      1197
# PS2           2161      2161      2161
# PS3           1331      1331      1331
# PS4            393       393       393
# PSP           1209      1209      1209
# PSV            432       432       432
# SAT            173       173       173
# SCD              6         6         6
# ...

# %%
x1 = df.groupby('Platform')['Platform'].count()
x1
# Out:
# Platform
# 2600     133
# 3DO        3
# 3DS      520
# DC        52
# DS      2152
# GB        98
# GBA      822
# GC       556
# GEN       29
# GG         1
# N64      319
# NES       98
# NG        12
# PC       974
# PCFX       1
# PS      1197
# PS2     2161
# PS3     1331
# PS4      393
# PSP     1209
# PSV      432
# SAT      173
# SCD        6
# SNES     239
# TG16       2
# WS         6
# Wii     1320
# WiiU     147
# X360    1262
# XB       824
# XOne     247
# Name: Platform, dtype: int64

# %%
df[["NA_Sales"]].mean().round(2)
# Out:
# NA_Sales    0.26
# dtype: float64

# %%
df1 = df[['Name', 'Platform', 'Year_of_Release', 'Publisher', "NA_Sales", "EU_Sales", "JP_Sales"]]
df1.query('Year_of_Release == 2003').sort_values("NA_Sales", ascending=False).head(1)
# Out:
#                           Name Platform  Year_of_Release Publisher  NA_Sales  \
# 112  Mario Kart: Double Dash!!       GC           2003.0  Nintendo      4.12
#
#      EU_Sales  JP_Sales
# 112      1.77      0.87

# %%
df2 = df[['Name', 'Platform', 'Year_of_Release', 'Publisher', 'User_Score']]
df2.query('Year_of_Release == 2000').sort_values("User_Score", ascending=False).head()
# Out:
#                        Name Platform  Year_of_Release           Publisher  \
# 10999      Skies of Arcadia       DC           2000.0                Sega
# 16355               Deus Ex       PC           2000.0   Eidos Interactive
# 7521   Phantasy Star Online       DC           2000.0                Sega
# 438              Spider-Man       PS           2000.0          Activision
# 7231         Capcom vs. SNK       DC           2000.0  Virgin Interactive
#
#        User_Score
# 10999         9.4
# 16355         9.3
# 7521          9.1
# 438           9.0
# 7231          9.0

# %%
df2 = df[['Name', 'Platform', 'Year_of_Release', 'Publisher', 'User_Score']]
df2.query('Year_of_Release == 2014 & Platform == "WiiU"').sort_values('User_Score', ascending=False).head()
# Out:
#                                       Name Platform  Year_of_Release  \
# 110                           Mario Kart 8     WiiU           2014.0
# 1231  Donkey Kong Country: Tropical Freeze     WiiU           2014.0
# 1691        Captain Toad: Treasure Tracker     WiiU           2014.0
# 1627                       Hyrule Warriors     WiiU           2014.0
# 2687                           Bayonetta 2     WiiU           2014.0
#
#      Publisher  User_Score
# 110   Nintendo         9.1
# 1231  Nintendo         8.9
# 1691  Nintendo         8.6
# 1627  Nintendo         8.3
# 2687  Nintendo         8.2

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...
